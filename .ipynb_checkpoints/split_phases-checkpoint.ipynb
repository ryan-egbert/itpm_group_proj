# %%
import pandas as pd
import os
import numpy as np
import datetime as dt
from shutil import which, copyfileobj
import gzip

LOC = 'paris' # 'ny', 'paris', 'london'

print(len(os.listdir(f'./data/{LOC}/')))
if len(os.listdir(f'./data/{LOC}/')) == 0:
    if which('wget') is None:
        # %conda install wget
    if LOC == 'ny':
        # !wget http://data.insideairbnb.com/united-states/new-york-city/ny/2021-07-06/data/listings.csv.gz
        # !wget http://data.insideairbnb.com/united-states/new-york-city/ny/2021-07-06/data/reviews.csv.gz
    elif LOC == 'paris':
        # !wget http://data.insideairbnb.com/france/ile-de-france/paris/2021-07-06/data/listings.csv.gz
        # !wget http://data.insideairbnb.com/france/ile-de-france/paris/2021-07-06/data/reviews.csv.gz
    elif LOC == 'london':
        # !wget http://data.insideairbnb.com/united-kingdom/england/london/2021-07-06/data/listings.csv.gz
        # !wget http://data.insideairbnb.com/united-kingdom/england/london/2021-07-06/data/reviews.csv.gz

    with gzip.open(f'./reviews.csv.gz', 'rb') as f_in:
        with open(f'./data/{LOC}/reviews.csv', 'wb') as f_out:
            copyfileobj(f_in, f_out)
    with gzip.open(f'./listings.csv.gz', 'rb') as f_in:
        with open(f'./data/{LOC}/listings.csv', 'wb') as f_out:
            copyfileobj(f_in, f_out)
# Out:
# 5

# %%
filename = f"./data/{LOC}/reviews.csv"
df = pd.read_csv(filename)

# %%
import nltk

nltk.download('stopwords')
STOP_ENG = nltk.corpus.stopwords.words('english')
STOP_SPA = nltk.corpus.stopwords.words('spanish')
STOP_FRE = nltk.corpus.stopwords.words('french')
STOP_GER = nltk.corpus.stopwords.words('german')

STOP = STOP_ENG + STOP_SPA + STOP_FRE + STOP_GER
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ryanegbert/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0        2577  366217274  2019-01-02     28047930          Kate
# 1        5396       4824  2009-06-30        19995         Sarah
# 2        5396       4968  2009-07-03        20117         Chris
# 3        5396       5240  2009-07-08        22190     Annelaure
# 4        5396       9619  2009-09-10        11947          Jean
#
#                                             comments
# 0  Beautiful apartment in a really handy location...
# 1  Perfect location!! Nasrine was a delight and m...
# 2  This is a nice place in a great location in Pa...
# 3  Nice studio, very clean, very quiet, in a grea...
# 4  Superb location, great studio. \r<br/>A slice ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034195 entries, 0 to 1034194
# Data columns (total 6 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   listing_id     1034195 non-null  int64
#  1   id             1034195 non-null  int64
#  2   date           1034195 non-null  object
#  3   reviewer_id    1034195 non-null  int64
#  4   reviewer_name  1034195 non-null  object
#  5   comments       1033693 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 47.3+ MB

# %%
df.comments.astype(str)
# Out:
# 0          Beautiful apartment in a really handy location...
# 1          Perfect location!! Nasrine was a delight and m...
# 2          This is a nice place in a great location in Pa...
# 3          Nice studio, very clean, very quiet, in a grea...
# 4          Superb location, great studio. \r<br/>A slice ...
#                                  ...
# 1034190           Sonia très à l’écoute et très disponible ✅
# 1034191    Superbe petit studio, propre et idéalement pla...
# 1034192      Très bel appartement dans un très bon quartier.
# 1034193    Stylish and true to pictures, super clean, tas...
# 1034194    I am very impressed by the quality of the acco...
# Name: comments, Length: 1034195, dtype: object

# %%
df.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
df.comments = df.comments.astype(str)
df.date = pd.to_datetime(df.date)

df = df[df.date > pd.to_datetime(dt.date(2019,12,31))]

# %%
def replace_symbols(text):
    text = text.lower()
    symbols = ['.',',','<','\\','/','>','(',')','[',']','-','_','+','=','!','@','#','’','\'',':',';','?','$','&','*']
    for s in symbols:
        if s in text:
            text = text.replace(s, '')
    
    return ' '.join(word for word in text.split() if word not in STOP)


df['review_simple'] = df.comments.apply(replace_symbols)

# %%
start_p1 = pd.to_datetime(dt.date(2020,1,1))
end_p1 = pd.to_datetime(dt.date(2020,2,29))
start_p2 = pd.to_datetime(dt.date(2020,3,1))
end_p2 = pd.to_datetime(dt.date(2020,7,31))
start_p3 = pd.to_datetime(dt.date(2020,8,1))
end_p3 = pd.to_datetime(dt.date(2020,12,31))
start_p4 = pd.to_datetime(dt.date(2021,1,1))
end_p4 = pd.to_datetime('today')

# %%
df.shape
# Out:
# (165886, 7)

# %%
df.head()
# Out:
#      listing_id         id       date  reviewer_id reviewer_name  \
# 210        5396  588263108 2020-01-04    138392009        Tricia
# 211        5396  589499566 2020-01-06     28821240        Adrien
# 212        5396  607910128 2020-02-19     26509433       Roberto
# 213        5396  611549316 2020-02-27      8898065        Brenda
# 214        5396  612203113 2020-02-29     46597362       Carolyn
#
#                                               comments  \
# 210                                                 ..
# 211  Awesome, safe building, clean room, but more i...
# 212             Great location and very helpful host.
# 213  Location location location! This flat is perfe...
# 214  Great location. We were a bit bummed the wifi ...
#
#                                          review_simple
# 210
# 211  awesome safe building clean room importantly r...
# 212                        great location helpful host
# 213  location location location flat perfectly loca...
# 214  great location bit bummed wifi wasnt working w...

# %%
pre_covid = df[(df.date > start_p1) & (df.date < end_p1)]
covid = df[(df.date > start_p2) & (df.date < end_p2)]
pre_vaccine = df[(df.date > start_p3) & (df.date < end_p3)]
post_vaccine = df[(df.date > start_p4) & (df.date < end_p4)]

# %%
print(pre_covid.shape)
print(covid.shape)
print(pre_vaccine.shape)
print(post_vaccine.shape)
# Out:
# (41569, 7)
# (26223, 7)
# (39882, 7)
# (53304, 7)

# %%
pre_covid.head()
# Out:
#      listing_id         id       date  reviewer_id reviewer_name  \
# 210        5396  588263108 2020-01-04    138392009        Tricia
# 211        5396  589499566 2020-01-06     28821240        Adrien
# 212        5396  607910128 2020-02-19     26509433       Roberto
# 213        5396  611549316 2020-02-27      8898065        Brenda
# 514        7397  593522241 2020-01-16    226544295        Wesley
#
#                                               comments  \
# 210                                                 ..
# 211  Awesome, safe building, clean room, but more i...
# 212             Great location and very helpful host.
# 213  Location location location! This flat is perfe...
# 514  Nice appartment with all you need at a great l...
#
#                                          review_simple
# 210
# 211  awesome safe building clean room importantly r...
# 212                        great location helpful host
# 213  location location location flat perfectly loca...
# 514                nice appartment need great location

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download("vader_lexicon")
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/ryanegbert/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
num = 1
for df in [pre_covid, covid, pre_vaccine, post_vaccine]:
    print("DataFrame " + str(num) + "...")
    df['sentiment'] = df.review_simple.apply(sia.polarity_scores)
    df.sentiment = df.sentiment.apply(lambda x: x['compound'])
    num += 1
# Out:
# DataFrame 1...
# DataFrame 2...
# DataFrame 3...
# DataFrame 4...

# %%
pre_covid.head()
# Out:
#      listing_id         id       date  reviewer_id reviewer_name  \
# 210        5396  588263108 2020-01-04    138392009        Tricia
# 211        5396  589499566 2020-01-06     28821240        Adrien
# 212        5396  607910128 2020-02-19     26509433       Roberto
# 213        5396  611549316 2020-02-27      8898065        Brenda
# 514        7397  593522241 2020-01-16    226544295        Wesley
#
#                                               comments  \
# 210                                                 ..
# 211  Awesome, safe building, clean room, but more i...
# 212             Great location and very helpful host.
# 213  Location location location! This flat is perfe...
# 514  Nice appartment with all you need at a great l...
#
#                                          review_simple  sentiment
# 210                                                        0.0000
# 211  awesome safe building clean room importantly r...     0.9623
# 212                        great location helpful host     0.7845
# 213  location location location flat perfectly loca...     0.9926
# 514                nice appartment need great location     0.7845

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

dfs = ['pre_covid', 'covid', 'pre_vaccine', 'post_vaccine']

num = 0
for df in [pre_covid, covid, pre_vaccine, post_vaccine]:
    print('DataFrame ' + str(num + 1) + " ...")
    text = " ".join(review for review in df[df.sentiment < 0].review_simple)
    print ("There are {} words in the combination of all review.".format(len(text)))
    text = text.replace('place','').replace('stay','').replace('apartment','').replace('room','')

    wordcloud = WordCloud(max_font_size=100, max_words=200, background_color="white").generate(text)

    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.savefig(dfs[num] + f"_neg_{LOC}.png")
    plt.show()
    num += 1
# Out:
# DataFrame 1 ...
# There are 432581 words in the combination of all review.
# DataFrame 2 ...
# There are 393270 words in the combination of all review.
# DataFrame 3 ...
# There are 695840 words in the combination of all review.
# DataFrame 4 ...
# There are 926532 words in the combination of all review.

# %%
num = 0
for df in [pre_covid, covid, pre_vaccine, post_vaccine]:
    print('DataFrame ' + str(num + 1) + " ...")
    text = " ".join(review for review in df[df.sentiment > 0].review_simple)
    print ("There are {} words in the combination of all review.".format(len(text)))
    text = text.replace('place','').replace('stay','').replace('apartment','').replace('room','')

    wordcloud = WordCloud(max_font_size=100, max_words=200, background_color="white").generate(text)

    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.savefig(dfs[num] + f"_pos_{LOC}.png")
    plt.show()
    num += 1
# Out:
# DataFrame 1 ...
# There are 4449200 words in the combination of all review.
# DataFrame 2 ...
# There are 2139980 words in the combination of all review.
# DataFrame 3 ...
# There are 2465295 words in the combination of all review.
# DataFrame 4 ...
# There are 2844724 words in the combination of all review.

# %%
df[df.sentiment < 0].head()
# Out:
#       listing_id                  id       date  reviewer_id reviewer_name  \
# 235         5396           740021631 2021-03-18     76972962       Rébecca
# 249         5396  389605409496251107 2021-06-21     95831689     Dominique
# 1172       11487           748640095 2021-04-14    372013925        Maewen
# 2928       20823  387446918435893696 2021-06-18     60225378   Jean-Pierre
# 6502       41106           720711059 2021-01-02     15988334       Sabrina
#
#                                                comments  \
# 235   Guillaume et sa compagne sont géniaux.<br/>Un ...
# 249   L'immeuble est situé dans un quartier très agr...
# 1172  Appartement propre et très agréable à vivre, i...
# 2928  C'est un logement très accueillant et très coc...
# 6502  Djibril est un hôte parfait. La communication ...
#
#                                           review_simple  sentiment
# 235   guillaume compagne géniauxbrun accueil chaleur...     -0.128
# 249   limmeuble situé quartier très agréable tourist...     -0.128
# 1172  appartement propre très agréable vivre tout éq...     -0.128
# 2928  cest logement très accueillant très cocooning ...     -0.128
# 6502  djibril hôte parfait communication fluide tout...     -0.128
